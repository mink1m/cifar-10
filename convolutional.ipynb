# %% [markdown]
# ### Convolutional Neural Network for CIFAR-10

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np

from Cifar10 import Cifar10
import helpers
import random

# %%
# device configuration
# device = torch.device('mps' if torch.backends.mps.is_available() else ('cuda' if torch.cuda.is_available() else 'cpu'))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('cpu')

print(f'Using device {device}')

# consitency in training
torch.manual_seed(1234)
random.seed(1234)
# Out:
# Using device cuda

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 4

trainset = Cifar10(train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)

testset = Cifar10(train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
class Net1(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class Net2(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv_layer = nn.Sequential(
             nn.Conv2d(3, 32, 3),
             nn.Conv2d(32, 64, 3),
             nn.MaxPool2d(2,2),
             nn.Conv2d(64, 128, 3),
             nn.MaxPool2d(2, 2),
             nn.Conv2d(128, 256, 3),
             nn.MaxPool2d(2,2),
        )
        
        self.ff_layer = nn.Sequential(
            nn.Linear(1024, 640),
            nn.ReLU(inplace=True),
            nn.Linear(640, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.conv_layer(x)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.ff_layer(x)
        return x

class Net3(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv_layer = nn.Sequential(
             nn.Conv2d(3, 16, 3),
             nn.Conv2d(16, 64, 3),
             nn.AvgPool2d(2,2),
             nn.Conv2d(64, 128, 3),
             nn.MaxPool2d(2, 2),
             nn.Conv2d(128, 256, 3),
             nn.MaxPool2d(2,2),
        )
        
        self.ff_layer = nn.Sequential(
            nn.Linear(1024, 640),
            nn.ReLU(inplace=True),
            nn.Linear(640, 512),
            nn.ReLU(inplace=True),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.conv_layer(x)
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.ff_layer(x)
        return x

# %%
num_epochs = 3

# optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

param_options = [
    (optim.SGD, {'lr':0.001, 'momentum':0.9}, Net1, 'SGD Net1'),
    (optim.SGD, {'lr':0.001, 'momentum':0.9}, Net2, 'SGD Net2'),
    (optim.SGD, {'lr':0.001, 'momentum':0.9}, Net3, 'SGD Net3'),
    (optim.Adam, {'lr':0.001}, Net1, 'Adam Net1'),
    (optim.Adam, {'lr':0.001}, Net2, 'Adam Net2'),
    (optim.Adam, {'lr':0.001}, Net3, 'Adam Net3'),
]

metrics = []
for opt, kwargs, Net, label in param_options:
    net = Net().to(device)
    # loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = opt(net.parameters(), **kwargs)
    loss_vals, tr_acc, te_acc  = helpers.train_model(net, trainloader, testloader, device, criterion, optimizer, num_epochs)

    metrics.append((loss_vals, tr_acc, te_acc, label))
# Out:
# starting training
# [1,  2000] loss: 2.173 tr acc: 0.271 te acc: 0.266
# [1,  4000] loss: 1.893 tr acc: 0.323 te acc: 0.322
# [1,  6000] loss: 1.716 tr acc: 0.407 te acc: 0.405
# [1,  8000] loss: 1.607 tr acc: 0.457 te acc: 0.457
# [1, 10000] loss: 1.529 tr acc: 0.462 te acc: 0.458
# [2,  2000] loss: 1.467 tr acc: 0.505 te acc: 0.493
# [2,  4000] loss: 1.404 tr acc: 0.499 te acc: 0.486
# [2,  6000] loss: 1.379 tr acc: 0.514 te acc: 0.495
# [2,  8000] loss: 1.344 tr acc: 0.503 te acc: 0.491
# [2, 10000] loss: 1.306 tr acc: 0.578 te acc: 0.556
# [3,  2000] loss: 1.243 tr acc: 0.545 te acc: 0.525
# [3,  4000] loss: 1.249 tr acc: 0.590 te acc: 0.561
# [3,  6000] loss: 1.217 tr acc: 0.604 te acc: 0.568
# [3,  8000] loss: 1.207 tr acc: 0.605 te acc: 0.577
# [3, 10000] loss: 1.226 tr acc: 0.555 te acc: 0.528
# Finished Training
# starting training
# [1,  2000] loss: 2.126 tr acc: 0.306 te acc: 0.306
# [1,  4000] loss: 1.781 tr acc: 0.386 te acc: 0.387
# [1,  6000] loss: 1.581 tr acc: 0.457 te acc: 0.453
# [1,  8000] loss: 1.466 tr acc: 0.504 te acc: 0.493
# [1, 10000] loss: 1.379 tr acc: 0.545 te acc: 0.528
# [2,  2000] loss: 1.286 tr acc: 0.577 te acc: 0.560
# [2,  4000] loss: 1.216 tr acc: 0.594 te acc: 0.573
# [2,  6000] loss: 1.184 tr acc: 0.584 te acc: 0.563
# [2,  8000] loss: 1.110 tr acc: 0.650 te acc: 0.619
# [2, 10000] loss: 1.050 tr acc: 0.679 te acc: 0.638
# [3,  2000] loss: 0.904 tr acc: 0.701 te acc: 0.661
# [3,  4000] loss: 0.918 tr acc: 0.713 te acc: 0.663
# [3,  6000] loss: 0.919 tr acc: 0.676 te acc: 0.635
# [3,  8000] loss: 0.905 tr acc: 0.744 te acc: 0.688
# [3, 10000] loss: 0.887 tr acc: 0.752 te acc: 0.689
# Finished Training
# starting training
# [1,  2000] loss: 2.166 tr acc: 0.266 te acc: 0.264
# [1,  4000] loss: 1.791 tr acc: 0.396 te acc: 0.388
# [1,  6000] loss: 1.612 tr acc: 0.447 te acc: 0.444
# [1,  8000] loss: 1.525 tr acc: 0.485 te acc: 0.479
# [1, 10000] loss: 1.429 tr acc: 0.511 te acc: 0.492
# [2,  2000] loss: 1.334 tr acc: 0.554 te acc: 0.544
# [2,  4000] loss: 1.295 tr acc: 0.578 te acc: 0.552
# [2,  6000] loss: 1.234 tr acc: 0.616 te acc: 0.583
# [2,  8000] loss: 1.183 tr acc: 0.612 te acc: 0.575
# [2, 10000] loss: 1.132 tr acc: 0.639 te acc: 0.598
# [3,  2000] loss: 1.025 tr acc: 0.645 te acc: 0.604
# [3,  4000] loss: 1.017 tr acc: 0.675 te acc: 0.624
# [3,  6000] loss: 1.015 tr acc: 0.699 te acc: 0.637
# [3,  8000] loss: 1.023 tr acc: 0.678 te acc: 0.618
# [3, 10000] loss: 0.969 tr acc: 0.719 te acc: 0.658
# Finished Training
# starting training
# [1,  2000] loss: 1.842 tr acc: 0.406 te acc: 0.402
# [1,  4000] loss: 1.591 tr acc: 0.445 te acc: 0.432
# [1,  6000] loss: 1.504 tr acc: 0.450 te acc: 0.450
# [1,  8000] loss: 1.451 tr acc: 0.512 te acc: 0.499
# [1, 10000] loss: 1.409 tr acc: 0.513 te acc: 0.501
# [2,  2000] loss: 1.343 tr acc: 0.500 te acc: 0.489
# [2,  4000] loss: 1.342 tr acc: 0.530 te acc: 0.513
# [2,  6000] loss: 1.344 tr acc: 0.543 te acc: 0.522
# [2,  8000] loss: 1.301 tr acc: 0.530 te acc: 0.505
# [2, 10000] loss: 1.284 tr acc: 0.562 te acc: 0.532
# [3,  2000] loss: 1.238 tr acc: 0.558 te acc: 0.533
# [3,  4000] loss: 1.231 tr acc: 0.558 te acc: 0.530
# [3,  6000] loss: 1.228 tr acc: 0.580 te acc: 0.546
# [3,  8000] loss: 1.225 tr acc: 0.569 te acc: 0.540
# [3, 10000] loss: 1.226 tr acc: 0.596 te acc: 0.561
# Finished Training
# starting training
# [1,  2000] loss: 2.013 tr acc: 0.369 te acc: 0.364
# [1,  4000] loss: 1.714 tr acc: 0.396 te acc: 0.401
# [1,  6000] loss: 1.531 tr acc: 0.515 te acc: 0.508
# [1,  8000] loss: 1.414 tr acc: 0.534 te acc: 0.528
# [1, 10000] loss: 1.360 tr acc: 0.561 te acc: 0.548
# [2,  2000] loss: 1.284 tr acc: 0.558 te acc: 0.541
# [2,  4000] loss: 1.271 tr acc: 0.585 te acc: 0.565
# [2,  6000] loss: 1.267 tr acc: 0.600 te acc: 0.578
# [2,  8000] loss: 1.237 tr acc: 0.586 te acc: 0.563
# [2, 10000] loss: 1.195 tr acc: 0.648 te acc: 0.618
# [3,  2000] loss: 1.121 tr acc: 0.655 te acc: 0.623
# [3,  4000] loss: 1.132 tr acc: 0.619 te acc: 0.591
# [3,  6000] loss: 1.156 tr acc: 0.596 te acc: 0.564
# [3,  8000] loss: 1.149 tr acc: 0.667 te acc: 0.621
# [3, 10000] loss: 1.166 tr acc: 0.682 te acc: 0.635
# Finished Training
# starting training
# [1,  2000] loss: 1.985 tr acc: 0.372 te acc: 0.368
# [1,  4000] loss: 1.644 tr acc: 0.477 te acc: 0.469
# [1,  6000] loss: 1.521 tr acc: 0.523 te acc: 0.511
# [1,  8000] loss: 1.445 tr acc: 0.549 te acc: 0.532
# [1, 10000] loss: 1.391 tr acc: 0.550 te acc: 0.532
# [2,  2000] loss: 2.185 tr acc: 0.100 te acc: 0.102
# [2,  4000] loss: 2.304 tr acc: 0.101 te acc: 0.098
# [2,  6000] loss: 2.303 tr acc: 0.100 te acc: 0.100
# [2,  8000] loss: 2.303 tr acc: 0.100 te acc: 0.100
# [2, 10000] loss: 2.314 tr acc: 0.100 te acc: 0.100
# [3,  2000] loss: 2.303 tr acc: 0.100 te acc: 0.100
# [3,  4000] loss: 2.303 tr acc: 0.100 te acc: 0.100
# [3,  6000] loss: 2.303 tr acc: 0.102 te acc: 0.097
# [3,  8000] loss: 2.404 tr acc: 0.101 te acc: 0.098
# [3, 10000] loss: 2.303 tr acc: 0.101 te acc: 0.098
# Finished Training

# %%
fig, axes = plt.subplots(3, 2, figsize=(10,10))


for idx, (loss_vals, tr_acc, te_acc, label) in enumerate(metrics):
    # ax1, ax2 = axes[idx]
    ax = axes[idx%3][idx//3]
    # ax1.plot(range(len(loss_vals)), loss_vals, label=f'Loss {label}')
    ax.plot(range(len(loss_vals)), tr_acc, label=f'train acc {label}')
    ax.plot(range(len(loss_vals)), te_acc, label=f'test acc {label}')

    ax.set_title(label)
    ax.legend()
    # ax2.legend()

plt.tight_layout()
plt.show()

metrics
# Out:
# [([2.1730478204488755,
#    1.8928903277516365,
#    1.7162614613473415,
#    1.6073968781232835,
#    1.5286704963594675,
#    1.4665121409371495,
#    1.403896660387516,
#    1.3785967994481325,
#    1.3436045818775892,
#    1.305817119039595,
#    1.2430742075666785,
#    1.2485161770135165,
#    1.2167545849308372,
#    1.2068133254423739,
#    1.2259328517615795,
#    0.0],
#   [0.2714,
#    0.323325,
#    0.4066,
#    0.457075,
#    0.46205,
#    0.505325,
#    0.49915,
#    0.5138,
#    0.50345,
#    0.5781,
#    0.5455,
#    0.5901,
#    0.604475,
#    0.604825,
#    0.554875,
#    0.554875],
#   [0.2656,
#    0.3217,
#    0.4053,
#    0.4569,
#    0.4581,
#    0.4931,
#    0.4857,
#    0.4947,
#    0.4907,
#    0.5556,
#    0.525,
#    0.5607,
#    0.5682,
#    0.5769,
#    0.5278,
#    0.5278],
#   'SGD Net1'),
#  ([2.125667357712984,
#    1.7807545824348927,
#    1.5813671719133855,
#    1.465566455118358,
#    1.3794890927523376,
#    1.2855425187535583,
#    1.2164752675406634,
#    1.1835204374194146,
#    1.110253740196582,
#    1.0501886914651841,
#    0.9038958728453145,
#    0.9182150432583875,
#    0.9191808150210418,
#    0.905262553401757,
#    0.8873907967810519,
#    0.0],
#   [0.3058,
#    0.3864,
#    0.45675,
#    0.504375,
#    0.545475,
#    0.5774,
#    0.5936,
#    0.58395,
#    0.650375,
#    0.67925,
#    0.700725,
#    0.71305,
#    0.675575,
#    0.7435,
#    0.752225,
#    0.752225],
#   [0.306,
#    0.3868,
#    0.4526,
#    0.4935,
#    0.5277,
#    0.5599,
#    0.5726,
#    0.5628,
#    0.6188,
#    0.6382,
#    0.6612,
#    0.6628,
#    0.6351,
#    0.6877,
#    0.6894,
#    0.6894],
#   'SGD Net2'),
#  ([2.165512050807476,
#    1.7912099386453628,
#    1.6118087378740311,
#    1.5245815248936414,
#    1.428648458868265,
#    1.3335051269978284,
#    1.2945304574519396,
#    1.2340153183229268,
#    1.183347192235291,
#    1.1324147206805646,
#    1.0246622673487291,
#    1.0173145087640731,
#    1.0154992814529686,
#    1.0227639403864741,
#    0.9685251157646999,
#    0.0],
#   [0.265725,
#    0.3955,
#    0.4467,
#    0.48545,
#    0.511075,
#    0.55405,
#    0.578425,
#    0.616125,
#    0.612,
#    0.63875,
#    0.6446,
#    0.674725,
#    0.69895,
#    0.67825,
#    0.71935,
#    0.71935],
#   [0.2638,
#    0.388,
#    0.4439,
#    0.4795,
#    0.4923,
#    0.5437,
#    0.5524,
#    0.5826,
#    0.5748,
#    0.5984,
#    0.6043,
#    0.6238,
#    0.6367,
#    0.6177,
#    0.6578,
#    0.6578],
#   'SGD Net3'),
#  ([1.841908624202013,
#    1.591062767237425,
#    1.5038368024975062,
#    1.451445960700512,
#    1.4089543875083328,
#    1.343355403624475,
#    1.3417383665442466,
#    1.3435749258305878,
#    1.301007746513933,
#    1.283956412702799,
#    1.2377542917132378,
#    1.2313759844638408,
#    1.2277641606591643,
#    1.2248719846457243,
#    1.2260094431452453,
#    0.0],
#   [0.40605,
#    0.44515,
#    0.4501,
#    0.511875,
#    0.5126,
#    0.499775,
#    0.5305,
#    0.543425,
#    0.529925,
#    0.56205,
#    0.55805,
#    0.5576,
#    0.57965,
#    0.56935,
#    0.59595,
#    0.59595],
#   [0.402,
#    0.4325,
#    0.4503,
#    0.4986,
#    0.5008,
#    0.4895,
#    0.5132,
#    0.5224,
#    0.5046,
#    0.5318,
#    0.5329,
#    0.5304,
#    0.5465,
#    0.5403,
#    0.5608,
#    0.5608],
#   'Adam Net1'),
#  ([2.0125805208981036,
#    1.7141025980263949,
#    1.5308913349881768,
#    1.4143822438940405,
#    1.3600487699303776,
#    1.2842760332031176,
#    1.2711351512819529,
#    1.2671744913673029,
#    1.2373626513238996,
#    1.1952028841325082,
#    1.1205546551947483,
#    1.1323634331058712,
#    1.156403811704833,
#    1.1486217161789536,
#    1.1657141122170724,
#    0.0],
#   [0.3689,
#    0.396225,
#    0.5146,
#    0.533625,
#    0.561225,
#    0.558275,
#    0.584725,
#    0.5999,
#    0.5861,
#    0.64795,
#    0.655175,
#    0.6191,
#    0.5964,
#    0.66705,
#    0.6817,
#    0.6817],
#   [0.3636,
#    0.4006,
#    0.5084,
#    0.5279,
#    0.5485,
#    0.5409,
#    0.5654,
#    0.5781,
#    0.5631,
#    0.6176,
#    0.6232,
#    0.5912,
#    0.5638,
#    0.6211,
#    0.6354,
#    0.6354],
#   'Adam Net2'),
#  ([1.9849814877808094,
#    1.644094126984477,
#    1.5213109761960804,
#    1.4451588835567235,
#    1.3905427140388638,
#    2.1847231940552594,
#    2.3035238847732544,
#    2.3031093648672103,
#    2.303060387134552,
#    2.3140336084365845,
#    2.3027098581790924,
#    2.3030801092386244,
#    2.3030148519277573,
#    2.4038268446922304,
#    2.302973475813866,
#    0.0],
#   [0.371575,
#    0.4771,
#    0.52255,
#    0.548825,
#    0.550175,
#    0.1002,
#    0.1009,
#    0.10045,
#    0.099925,
#    0.099925,
#    0.10045,
#    0.10045,
#    0.101575,
#    0.1009,
#    0.1009,
#    0.1009],
#   [0.3684,
#    0.4686,
#    0.5107,
#    0.5325,
#    0.5316,
#    0.1016,
#    0.0981,
#    0.1001,
#    0.0999,
#    0.0999,
#    0.1001,
#    0.1001,
#    0.0974,
#    0.0981,
#    0.0981,
#    0.0981],
#   'Adam Net3')]

# %%
net = Net2().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
loss_vals, tr_acc, te_acc  = helpers.train_model(net, trainloader, testloader, device, criterion, optimizer, num_epochs)
# Out:
# starting training
# [1,  2000] loss: 2.190 tr acc: 0.265 te acc: 0.264
# [1,  4000] loss: 1.816 tr acc: 0.401 te acc: 0.394
# [1,  6000] loss: 1.589 tr acc: 0.474 te acc: 0.465
# [1,  8000] loss: 1.494 tr acc: 0.472 te acc: 0.465
# [1, 10000] loss: 1.383 tr acc: 0.541 te acc: 0.534
# [2,  2000] loss: 1.281 tr acc: 0.531 te acc: 0.514
# [2,  4000] loss: 1.228 tr acc: 0.613 te acc: 0.587
# [2,  6000] loss: 1.162 tr acc: 0.627 te acc: 0.593
# [2,  8000] loss: 1.103 tr acc: 0.664 te acc: 0.626
# [2, 10000] loss: 1.053 tr acc: 0.671 te acc: 0.636
# [3,  2000] loss: 0.946 tr acc: 0.695 te acc: 0.650
# [3,  4000] loss: 0.915 tr acc: 0.721 te acc: 0.661
# [3,  6000] loss: 0.890 tr acc: 0.712 te acc: 0.651
# [3,  8000] loss: 0.896 tr acc: 0.713 te acc: 0.660
# [3, 10000] loss: 0.865 tr acc: 0.742 te acc: 0.673
# Finished Training

# %%
torch.save(net.state_dict(), './CNN_net.pth')

# %%
net = Net2()
net.load_state_dict(torch.load('./CNN_net.pth'))
net.eval()


# print(helpers.evaluate(net, testloader, 'cpu'))

helpers.show_errors(net, testloader, classes, 20)
# Out:
# GroundTruth:  bird  plane truck dog
# Predicted:  plane cat   bird  bird
# GroundTruth:  bird  truck bird  dog
# Predicted:  frog  car   cat   cat
# GroundTruth:  plane deer  car   ship
# Predicted:  cat   truck plane dog
# GroundTruth:  truck deer  dog   horse
# Predicted:  car   plane deer  deer
# GroundTruth:  plane bird  cat   truck
# Predicted:  car   frog  deer  cat
# GroundTruth:  bird  deer  dog   horse
# Predicted:  cat   bird  cat   deer
# GroundTruth:  bird  ship  truck bird
# Predicted:  deer  truck horse cat
# GroundTruth:  ship  ship  car   plane
# Predicted:  plane horse dog   car
# GroundTruth:  plane cat   cat   horse
# Predicted:  ship  dog   deer  deer
# GroundTruth:  bird  plane plane deer
# Predicted:  cat   car   frog  cat
# GroundTruth:  dog   deer  cat   horse
# Predicted:  cat   dog   deer  dog
# GroundTruth:  horse bird  ship  cat
# Predicted:  dog   frog  bird  frog
# GroundTruth:  dog   cat   frog  dog
# Predicted:  cat   dog   dog   cat
# GroundTruth:  truck dog   cat   frog
# Predicted:  cat   bird  deer  cat
# GroundTruth:  bird  cat   frog  horse
# Predicted:  cat   deer  bird  deer
# GroundTruth:  cat   deer  frog  bird
# Predicted:  dog   frog  cat   plane
# GroundTruth:  horse cat   bird  cat
# Predicted:  deer  deer  frog  deer
# GroundTruth:  dog   bird  frog  ship
# Predicted:  cat   dog   bird  plane
# GroundTruth:  dog   bird  bird  dog
# Predicted:  bird  plane plane deer
# GroundTruth:  ship  deer  horse truck
# Predicted:  plane cat   bird  ship
# GroundTruth:  frog  car   frog  cat
# Predicted:  cat   dog   cat   frog
